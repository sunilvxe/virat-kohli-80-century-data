# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/virat-kohli-80-century-dataset-all-matches/virat_kohli_80_centuries.csv

# %%
import pandas as pd

# Test Centuries by Virat Kohli
test_centuries = [
    {"No.": 1, "Runs": 116, "Against": "Australia", "Pos.": 6, "Inn.": 2, "Test": "4/4", "Venue": "Adelaide Oval, Adelaide", "H/A": "Away", "Date": "24 January 2012", "Result": "Lost"},
    {"No.": 2, "Runs": 103, "Against": "New Zealand", "Pos.": 5, "Inn.": 2, "Test": "2/2", "Venue": "M. Chinnaswamy Stadium, Bangalore", "H/A": "Home", "Date": "31 August 2012", "Result": "Won"},
    {"No.": 3, "Runs": 103, "Against": "England", "Pos.": 5, "Inn.": 2, "Test": "4/4", "Venue": "Vidarbha Cricket Association Stadium, Nagpur", "H/A": "Home", "Date": "13 December 2012", "Result": "Drawn"},
    {"No.": 4, "Runs": 107, "Against": "Australia", "Pos.": 5, "Inn.": 2, "Test": "1/4", "Venue": "M. A. Chidambaram Stadium, Chennai", "H/A": "Home", "Date": "22 February 2013", "Result": "Won"},
    {"No.": 5, "Runs": 119, "Against": "South Africa", "Pos.": 4, "Inn.": 1, "Test": "1/2", "Venue": "Wanderers Stadium, Johannesburg", "H/A": "Away", "Date": "18 December 2013", "Result": "Drawn"},
    {"No.": 6, "Runs": 105, "Against": "New Zealand", "Pos.": 4, "Inn.": 4, "Test": "2/2", "Venue": "Basin Reserve, Wellington", "H/A": "Away", "Date": "14 February 2014", "Result": "Drawn"},
    {"No.": 7, "Runs": 115, "Against": "Australia", "Pos.": 4, "Inn.": 2, "Test": "1/4", "Venue": "Adelaide Oval, Adelaide", "H/A": "Away", "Date": "9 December 2014", "Result": "Lost"},
    {"No.": 8, "Runs": 141, "Against": "Australia", "Pos.": 4, "Inn.": 4, "Test": "1/4", "Venue": "Adelaide Oval, Adelaide", "H/A": "Away", "Date": "9 December 2014", "Result": "Lost"},
    {"No.": 9, "Runs": 169, "Against": "Australia", "Pos.": 4, "Inn.": 2, "Test": "3/4", "Venue": "Melbourne Cricket Ground, Melbourne", "H/A": "Away", "Date": "26 December 2014", "Result": "Drawn"},
    {"No.": 10, "Runs": 147, "Against": "Australia", "Pos.": 4, "Inn.": 2, "Test": "4/4", "Venue": "Sydney Cricket Ground, Sydney", "H/A": "Away", "Date": "6 January 2015", "Result": "Drawn"},
    {"No.": 11, "Runs": 103, "Against": "Sri Lanka", "Pos.": 4, "Inn.": 2, "Test": "1/3", "Venue": "Galle International Stadium, Galle", "H/A": "Away", "Date": "12 August 2015", "Result": "Lost"},
    {"No.": 12, "Runs": 200, "Against": "West Indies", "Pos.": 4, "Inn.": 1, "Test": "1/4", "Venue": "Sir Vivian Richards Stadium, Antigua", "H/A": "Away", "Date": "21 July 2016", "Result": "Won"},
    {"No.": 13, "Runs": 211, "Against": "New Zealand", "Pos.": 4, "Inn.": 1, "Test": "3/3", "Venue": "Holkar Stadium, Indore", "H/A": "Home", "Date": "8 October 2016", "Result": "Won"},
    {"No.": 14, "Runs": 167, "Against": "England", "Pos.": 4, "Inn.": 1, "Test": "2/5", "Venue": "ACA-VDCA Cricket Stadium, Visakhapatnam", "H/A": "Home", "Date": "17 November 2016", "Result": "Won"},
    {"No.": 15, "Runs": 235, "Against": "England", "Pos.": 4, "Inn.": 2, "Test": "4/5", "Venue": "Wankhede Stadium, Mumbai", "H/A": "Home", "Date": "8 December 2016", "Result": "Won"},
    {"No.": 16, "Runs": 204, "Against": "Bangladesh", "Pos.": 4, "Inn.": 1, "Test": "1/1", "Venue": "Rajiv Gandhi Stadium, Hyderabad", "H/A": "Home", "Date": "9 February 2017", "Result": "Won"},
    {"No.": 17, "Runs": 103, "Against": "Sri Lanka", "Pos.": 4, "Inn.": 3, "Test": "1/3", "Venue": "Galle International Stadium, Galle", "H/A": "Away", "Date": "26 July 2017", "Result": "Won"},
    {"No.": 18, "Runs": 104, "Against": "Sri Lanka", "Pos.": 4, "Inn.": 3, "Test": "1/3", "Venue": "Eden Gardens, Kolkata", "H/A": "Home", "Date": "16 November 2017", "Result": "Drawn"},
    {"No.": 19, "Runs": 213, "Against": "Sri Lanka", "Pos.": 4, "Inn.": 2, "Test": "2/3", "Venue": "Vidarbha Cricket Association Stadium, Nagpur", "H/A": "Home", "Date": "24 November 2017", "Result": "Won"},
    {"No.": 20, "Runs": 243, "Against": "Sri Lanka", "Pos.": 4, "Inn.": 1, "Test": "3/3", "Venue": "Feroz Shah Kotla Ground, Delhi", "H/A": "Home", "Date": "2 December 2017", "Result": "Drawn"},
    {"No.": 21, "Runs": 153, "Against": "South Africa", "Pos.": 4, "Inn.": 2, "Test": "2/3", "Venue": "SuperSport Park, Centurion", "H/A": "Away", "Date": "13 January 2018", "Result": "Lost"},
    {"No.": 22, "Runs": 149, "Against": "England", "Pos.": 4, "Inn.": 2, "Test": "1/5", "Venue": "Edgbaston, Birmingham", "H/A": "Away", "Date": "1 August 2018", "Result": "Lost"},
    {"No.": 23, "Runs": 103, "Against": "England", "Pos.": 4, "Inn.": 3, "Test": "3/5", "Venue": "Trent Bridge, Nottingham", "H/A": "Away", "Date": "18 August 2018", "Result": "Won"},
    {"No.": 24, "Runs": 139, "Against": "West Indies", "Pos.": 4, "Inn.": 1, "Test": "1/2", "Venue": "Saurashtra Cricket Association Stadium, Rajkot", "H/A": "Home", "Date": "4 October 2018", "Result": "Won"},
    {"No.": 25, "Runs": 123, "Against": "Australia", "Pos.": 4, "Inn.": 2, "Test": "2/4", "Venue": "Perth Stadium, Perth", "H/A": "Away", "Date": "14 December 2018", "Result": "Lost"},
    {"No.": 26, "Runs": 254, "Against": "South Africa", "Pos.": 4, "Inn.": 1, "Test": "2/3", "Venue": "Maharashtra Cricket Association Stadium, Pune", "H/A": "Home", "Date": "10 October 2019", "Result": "Won"},
    {"No.": 27, "Runs": 136, "Against": "Bangladesh", "Pos.": 4, "Inn.": 2, "Test": "2/2", "Venue": "Eden Gardens, Kolkata", "H/A": "Home", "Date": "22 November 2019", "Result": "Won"},
    {"No.": 28, "Runs": 186, "Against": "Australia", "Pos.": 4, "Inn.": 2, "Test": "4/4", "Venue": "Narendra Modi Stadium, Ahmedabad", "H/A": "Home", "Date": "9 March 2023", "Result": "Drawn"},
    {"No.": 29, "Runs": 121, "Against": "West Indies", "Pos.": 4, "Inn.": 1, "Test": "2/2", "Venue": "Queen's Park Oval, Port of Spain", "H/A": "Away", "Date": "20 July 2023", "Result": "Drawn"}
]

odi_centuries = [
    {"No.": 1, "Runs": 107, "Against": "Sri Lanka", "Pos.": 4, "Inn.": 2, "S/R": 93.85, "Venue": "Eden Gardens, Kolkata", "H/A/N": "Home", "Date": "24 December 2009", "Result": "Won"},
    {"No.": 2, "Runs": 102, "Against": "Bangladesh", "Pos.": 3, "Inn.": 2, "S/R": 107.37, "Venue": "Sher-e-Bangla Stadium, Dhaka", "H/A/N": "Away", "Date": "11 January 2010", "Result": "Won"},
    {"No.": 3, "Runs": 118, "Against": "Australia", "Pos.": 3, "Inn.": 2, "S/R": 97.52, "Venue": "ACA–VDCA Cricket Stadium, Visakhapatnam", "H/A/N": "Home", "Date": "20 October 2010", "Result": "Won"},
    {"No.": 4, "Runs": 105, "Against": "New Zealand", "Pos.": 3, "Inn.": 1, "S/R": 100.96, "Venue": "Nehru Stadium, Guwahati", "H/A/N": "Home", "Date": "28 November 2010", "Result": "Won"},
    {"No.": 5, "Runs": 100, "Against": "Bangladesh", "Pos.": 4, "Inn.": 1, "S/R": 120.48, "Venue": "Sher-e-Bangla Stadium, Dhaka", "H/A/N": "Away", "Date": "19 February 2011", "Result": "Won"},
    {"No.": 6, "Runs": 107, "Against": "England", "Pos.": 4, "Inn.": 1, "S/R": 115.05, "Venue": "Sophia Gardens, Cardiff", "H/A/N": "Away", "Date": "16 September 2011", "Result": "Lost (D/L)"},
    {"No.": 7, "Runs": 112, "Against": "England", "Pos.": 4, "Inn.": 2, "S/R": 114.28, "Venue": "Feroz Shah Kotla Ground, Delhi", "H/A/N": "Home", "Date": "17 October 2011", "Result": "Won"},
    {"No.": 8, "Runs": 117, "Against": "West Indies", "Pos.": 4, "Inn.": 2, "S/R": 95.12, "Venue": "ACA–VDCA Cricket Stadium, Visakhapatnam", "H/A/N": "Home", "Date": "2 December 2011", "Result": "Won"},
    {"No.": 9, "Runs": 133, "Against": "Sri Lanka", "Pos.": 4, "Inn.": 2, "S/R": 154.65, "Venue": "Bellerive Oval, Hobart", "H/A/N": "Neutral", "Date": "28 February 2012", "Result": "Won"},
    {"No.": 10, "Runs": 108, "Against": "Sri Lanka", "Pos.": 3, "Inn.": 1, "S/R": 90.00, "Venue": "Sher-e-Bangla Stadium, Dhaka", "H/A/N": "Neutral", "Date": "13 March 2012", "Result": "Won"},
    {"No.": 11, "Runs": 183, "Against": "Pakistan", "Pos.": 3, "Inn.": 2, "S/R": 123.64, "Venue": "Sher-e-Bangla Stadium, Dhaka", "H/A/N": "Neutral", "Date": "18 March 2012", "Result": "Won"},
    {"No.": 12, "Runs": 106, "Against": "Sri Lanka", "Pos.": 3, "Inn.": 1, "S/R": 93.80, "Venue": "MRIC Stadium, Hambantota", "H/A/N": "Away", "Date": "21 July 2012", "Result": "Won"},
    {"No.": 13, "Runs": 128, "Against": "Sri Lanka", "Pos.": 3, "Inn.": 2, "S/R": 107.56, "Venue": "R. Premadasa Stadium, Colombo", "H/A/N": "Away", "Date": "31 July 2012", "Result": "Won"},
    {"No.": 14, "Runs": 102, "Against": "West Indies", "Pos.": 3, "Inn.": 1, "S/R": 122.89, "Venue": "Queen's Park Oval, Port of Spain", "H/A/N": "Away", "Date": "5 July 2013", "Result": "Won (D/L)"},
    {"No.": 15, "Runs": 115, "Against": "Zimbabwe", "Pos.": 3, "Inn.": 2, "S/R": 106.48, "Venue": "Harare Sports Club, Harare", "H/A/N": "Away", "Date": "24 July 2013", "Result": "Won"},
    {"No.": 16, "Runs": 100, "Against": "Australia", "Pos.": 3, "Inn.": 2, "S/R": 192.30, "Venue": "Sawai Mansingh Stadium, Jaipur", "H/A/N": "Home", "Date": "16 October 2013", "Result": "Won"},
    {"No.": 17, "Runs": 115, "Against": "Australia", "Pos.": 3, "Inn.": 2, "S/R": 174.24, "Venue": "VCA Stadium, Nagpur", "H/A/N": "Home", "Date": "30 October 2013", "Result": "Won"},
    {"No.": 18, "Runs": 123, "Against": "New Zealand", "Pos.": 3, "Inn.": 2, "S/R": 110.81, "Venue": "McLean Park, Napier", "H/A/N": "Away", "Date": "19 January 2014", "Result": "Lost"},
    {"No.": 19, "Runs": 136, "Against": "Bangladesh", "Pos.": 3, "Inn.": 2, "S/R": 111.47, "Venue": "Khan Shaheb Osman Ali Stadium, Fatullah", "H/A/N": "Away", "Date": "26 February 2014", "Result": "Won"},
    {"No.": 20, "Runs": 127, "Against": "West Indies", "Pos.": 3, "Inn.": 1, "S/R": 111.40, "Venue": "HPCA Stadium, Dharamshala", "H/A/N": "Home", "Date": "17 October 2014", "Result": "Won"},
    {"No.": 21, "Runs": 139, "Against": "Sri Lanka", "Pos.": 4, "Inn.": 2, "S/R": 110.31, "Venue": "JSCA Stadium, Ranchi", "H/A/N": "Home", "Date": "16 November 2014", "Result": "Won"},
    {"No.": 22, "Runs": 107, "Against": "Pakistan", "Pos.": 3, "Inn.": 1, "S/R": 84.90, "Venue": "Adelaide Oval, Adelaide", "H/A/N": "Neutral", "Date": "15 February 2015", "Result": "Won"},
    {"No.": 23, "Runs": 138, "Against": "South Africa", "Pos.": 3, "Inn.": 1, "S/R": 98.57, "Venue": "M. A. Chidambaram Stadium, Chennai", "H/A/N": "Home", "Date": "22 October 2015", "Result": "Won"},
    {"No.": 24, "Runs": 117, "Against": "Australia", "Pos.": 3, "Inn.": 1, "S/R": 100.00, "Venue": "Melbourne Cricket Ground, Melbourne", "H/A/N": "Away", "Date": "17 January 2016", "Result": "Lost"},
    {"No.": 25, "Runs": 106, "Against": "Australia", "Pos.": 3, "Inn.": 2, "S/R": 115.21, "Venue": "Manuka Oval, Canberra", "H/A/N": "Away", "Date": "20 January 2016", "Result": "Lost"},
    {"No.": 26, "Runs": 154, "Against": "New Zealand", "Pos.": 3, "Inn.": 2, "S/R": 114.92, "Venue": "IS Bindra Stadium, Mohali", "H/A/N": "Home", "Date": "23 October 2016", "Result": "Won"},
    {"No.": 27, "Runs": 122, "Against": "England", "Pos.": 3, "Inn.": 2, "S/R": 116.19, "Venue": "Maharashtra Cricket Association Stadium, Pune", "H/A/N": "Home", "Date": "15 January 2017", "Result": "Won"},
    {"No.": 28, "Runs": 111, "Against": "West Indies", "Pos.": 3, "Inn.": 2, "S/R": 96.52, "Venue": "Sabina Park, Kingston", "H/A/N": "Away", "Date": "6 July 2017", "Result": "Won"},
    {"No.": 29, "Runs": 131, "Against": "Sri Lanka", "Pos.": 3, "Inn.": 1, "S/R": 136.45, "Venue": "R. Premadasa Stadium, Colombo", "H/A/N": "Away", "Date": "31 August 2017", "Result": "Won"},
    {"No.": 30, "Runs": 110, "Against": "Sri Lanka", "Pos.": 3, "Inn.": 2, "S/R": 94.82, "Venue": "R. Premadasa Stadium, Colombo", "H/A/N": "Away", "Date": "3 September 2017", "Result": "Won"},
    {"No.": 31, "Runs": 121, "Against": "New Zealand", "Pos.": 3, "Inn.": 1, "S/R": 96.80, "Venue": "Wankhede Stadium, Mumbai", "H/A/N": "Home", "Date": "22 October 2017", "Result": "Lost"},
    {"No.": 32, "Runs": 113, "Against": "New Zealand", "Pos.": 3, "Inn.": 1, "S/R": 106.60, "Venue": "Green Park Stadium, Kanpur", "H/A/N": "Home", "Date": "29 October 2017", "Result": "Won"},
    {"No.": 33, "Runs": 112, "Against": "South Africa", "Pos.": 3, "Inn.": 2, "S/R": 94.11, "Venue": "Kingsmead Cricket Ground, Durban", "H/A/N": "Away", "Date": "1 February 2018", "Result": "Won"},
    {"No.": 34, "Runs": 160, "Against": "South Africa", "Pos.": 3, "Inn.": 1, "S/R": 100.62, "Venue": "Newlands Cricket Ground, Cape Town", "H/A/N": "Away", "Date": "7 February 2018", "Result": "Won"},
    {"No.": 35, "Runs": 129, "Against": "South Africa", "Pos.": 3, "Inn.": 2, "S/R": 134.37, "Venue": "SuperSport Park, Centurion", "H/A/N": "Away", "Date": "16 February 2018", "Result": "Won"},
    {"No.": 36, "Runs": 140, "Against": "West Indies", "Pos.": 3, "Inn.": 2, "S/R": 130.84, "Venue": "ACA Stadium, Guwahati", "H/A/N": "Home", "Date": "21 October 2018", "Result": "Won"},
    {"No.": 37, "Runs": 157, "Against": "West Indies", "Pos.": 3, "Inn.": 1, "S/R": 121.71, "Venue": "ACA–VDCA Cricket Stadium, Visakhapatnam", "H/A/N": "Home", "Date": "24 October 2018", "Result": "Tied"},
    {"No.": 38, "Runs": 107, "Against": "West Indies", "Pos.": 3, "Inn.": 2, "S/R": 89.91, "Venue": "Maharashtra Cricket Association Stadium, Pune", "H/A/N": "Home", "Date": "27 October 2018", "Result": "Lost"},
    {"No.": 39, "Runs": 104, "Against": "Australia", "Pos.": 3, "Inn.": 2, "S/R": 92.85, "Venue": "Adelaide Oval, Adelaide", "H/A/N": "Away", "Date": "15 January 2019", "Result": "Won"},
    {"No.": 40, "Runs": 116, "Against": "Australia", "Pos.": 3, "Inn.": 1, "S/R": 96.67, "Venue": "Vidarbha Cricket Association Stadium, Nagpur", "H/A/N": "Home", "Date": "5 March 2019", "Result": "Won"},
    {"No.": 41, "Runs": 123, "Against": "Australia", "Pos.": 3, "Inn.": 2, "S/R": 129.47, "Venue": "JSCA Stadium, Ranchi", "H/A/N": "Home", "Date": "8 March 2019", "Result": "Lost"},
    {"No.": 42, "Runs": 120, "Against": "West Indies", "Pos.": 3, "Inn.": 1, "S/R": 96.00, "Venue": "Queen's Park Oval, Port of Spain", "H/A/N": "Away", "Date": "11 August 2019", "Result": "Won"},
    {"No.": 43, "Runs": 114, "Against": "West Indies", "Pos.": 3, "Inn.": 2, "S/R": 115.15, "Venue": "Queen's Park Oval, Port of Spain", "H/A/N": "Away", "Date": "14 August 2019", "Result": "Won"},
    {"No.": 44, "Runs": 113, "Against": "Bangladesh", "Pos.": 3, "Inn.": 1, "S/R": 124.17, "Venue": "Zohur Ahmed Chowdhury Stadium, Chittagong", "H/A/N": "Away", "Date": "10 December 2022", "Result": "Won"},
    {"No.": 45, "Runs": 113, "Against": "Sri Lanka", "Pos.": 3, "Inn.": 1, "S/R": 129.88, "Venue": "ACA Stadium, Guwahati", "H/A/N": "Home", "Date": "10 January 2023", "Result": "Won"},
    {"No.": 46, "Runs": 166, "Against": "Sri Lanka", "Pos.": 3, "Inn.": 1, "S/R": 150.90, "Venue": "Greenfield International Stadium, Thiruvananthapuram", "H/A/N": "Home", "Date": "15 January 2023", "Result": "Won"},
    {"No.": 47, "Runs": 122, "Against": "Pakistan", "Pos.": 3, "Inn.": 1, "S/R": 129.78, "Venue": "R. Premadasa Stadium, Colombo", "H/A/N": "Neutral", "Date": "10 September 2023", "Result": "Won"},
    {"No.": 48, "Runs": 103, "Against": "Bangladesh", "Pos.": 3, "Inn.": 2, "S/R": 106.18, "Venue": "Maharashtra Cricket Association Stadium, Pune", "H/A/N": "Home", "Date": "19 October 2023", "Result": "Won"},
    {"No.": 49, "Runs": 101, "Against": "South Africa", "Pos.": 3, "Inn.": 1, "S/R": 83.47, "Venue": "Eden Gardens, Kolkata", "H/A/N": "Home", "Date": "5 November 2023", "Result": "Won"},
    {"No.": 50, "Runs": 117, "Against": "New Zealand", "Pos.": 3, "Inn.": 1, "S/R": 103.53, "Venue": "Wankhede Stadium, Mumbai", "H/A/N": "Home", "Date": "15 November 2023", "Result": "Won"}
]

t20i_centuries = [
    {
        "No.": 1,
        "Runs": "122*",
        "Against": "Afghanistan",
        "Pos.": 2,
        "Inn.": 1,
        "S/R": 200.00,
        "Venue": "Dubai International Cricket Stadium, Dubai",
        "H/A/N": "Neutral",
        "Date": "8 September 2022",
        "Result": "Won"
    }
]


# Add the "Match Type" column manually for each dataset
for century in test_centuries:
    century["Match Type"] = "Test"

for century in odi_centuries:
    century["Match Type"] = "ODI"

for century in t20i_centuries:
    century["Match Type"] = "T20I"

# Combine all data into a single list
all_centuries = test_centuries + odi_centuries + t20i_centuries

# Create the DataFrame
df = pd.DataFrame(all_centuries)

# Add a new column 'H/A/N/N'
df['H/A/N/N'] = df.apply(lambda row: row['H/A'] if row['Match Type'] == 'Test' else row['H/A/N'], axis=1)
# Drop the original 'H/A/N' column as we no longer need it
df.drop(columns=["H/A/N"], inplace=True)

# Reorganize and fill in missing columns for consistency
df = df.reindex(columns=["No.", "Runs", "Against", "Pos.", "Inn.", "S/R", "Test", "Venue",  "H/A/N/N", "Date", "Result", "Match Type"])



# Display the DataFrame to verify
df.head()
# Out:
#    No. Runs       Against  Pos.  Inn.  S/R Test  \
# 0    1  116     Australia     6     2  NaN  4/4
# 1    2  103   New Zealand     5     2  NaN  2/2
# 2    3  103       England     5     2  NaN  4/4
# 3    4  107     Australia     5     2  NaN  1/4
# 4    5  119  South Africa     4     1  NaN  1/2
#
#                                           Venue H/A/N/N              Date  \
# 0                       Adelaide Oval, Adelaide    Away   24 January 2012
# 1             M. Chinnaswamy Stadium, Bangalore    Home    31 August 2012
# 2  Vidarbha Cricket Association Stadium, Nagpur    Home  13 December 2012
# 3            M. A. Chidambaram Stadium, Chennai    Home  22 February 2013
# 4               Wanderers Stadium, Johannesburg    Away  18 December 2013
#
#   Result Match Type
# 0   Lost       Test
# 1    Won       Test
# 2  Drawn       Test
# 3    Won       Test
# 4  Drawn       Test

# %%
df.rename(columns={'H/A/N/N': 'H/A/N'}, inplace=True)

# %%
df.isnull().sum()
# Out:
# No.            0
# Runs           0
# Against        0
# Pos.           0
# Inn.           0
# S/R           29
# Test          51
# Venue          0
# H/A/N          0
# Date           0
# Result         0
# Match Type     0
# dtype: int64

# %%
# df.to_csv("virat_kohli_80_centuries.csv", index=False)
